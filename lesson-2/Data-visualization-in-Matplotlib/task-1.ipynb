# %% [markdown]
# ### task-1

# %%
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline
# %config InlineBackend.figure_format='svg'

# %%
# x =np.linspace(1, 7, 7, dtype=int)
x = np.arange(1, 8)
y = np.array([3.5, 3.8, 4.2, 4.5, 5, 5.5, 7])
print(x)
y
# Out:
# [1 2 3 4 5 6 7]
# array([3.5, 3.8, 4.2, 4.5, 5. , 5.5, 7. ])

# %%
plt.plot(x, y)
plt.show()

# %%
plt.scatter(x,y)
plt.show()
